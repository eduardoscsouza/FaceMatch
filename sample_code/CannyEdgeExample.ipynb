# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../src/')

from preprocessing import cannyEdgeDetection

# %%
face_cascade = cv2.CascadeClassifier('../../data/lbpcascade_frontalface.xml')

# %%
image = cv2.imread('../data/Img/000001.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_f = cannyEdgeDetection(gray)
plt.axis('off')
_ = plt.imshow(image_f, cmap='gray')
