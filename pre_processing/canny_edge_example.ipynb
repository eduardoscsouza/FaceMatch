# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import canny_edge_detection

# %%
face_cascade = cv2.CascadeClassifier('data/lbpcascade_frontalface.xml')

# %%
image = cv2.imread('../sample_imgs/raw/000001.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_f = canny_edge_detection.cannyEdgeDetection(gray)

plt.imshow(image_f)
